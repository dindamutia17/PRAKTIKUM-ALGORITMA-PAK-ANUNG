# %%
"""
* Nama: Dinda Mutia
* NIM: 065002500020
* Tanggal: 18 September 2025
* Tugas: Luas Ruangan
"""

print("Hitung Luas Ruangan")
print("")
pr = int (input("Masukan Panjangan Ruangan:"))
lr = int (input("Masukan Lebar Ruangan:"))
rumus_meter = pr * lr
rumus_inci = (pr * 39.3701) * (lr * 39.3701)
print("")
print(f"Luas ruangan dengan panjang {pr} dan lebar {lr} adalah {rumus_meter} meter atau {rumus_inci} inci")
# Out:
# Hitung Luas Ruangan
#
# Masukan Panjangan Ruangan:5
# Masukan Lebar Ruangan:7
#
# Luas ruangan dengan panjang 5 dan lebar 7 adalah 35 meter atau 54250.167090350005 inci

# %%
"""
* Nama: Dinda Mutia
* NIM: 065002500020
* Tanggal: 18 September 2025
* Tugas: Menghitung BMI
"""

print("Body Mass Index(BMI)")
print("")
nama = input("Nama Kamu:")
bb = int (input("Berat Badan:"))
tb = int (input("Tinggi Badan:"))
("")
rumus = bb / (tb * tb)
print("")
print(f"Skor BMI kamu adalah {rumus}")
# Out:
# Body Mass Index(BMI)
#
# Nama Kamu:dinda
# Berat Badan:50
# Tinggi Badan:160
#
# Skor BMI kamu adalah 0.001953125
