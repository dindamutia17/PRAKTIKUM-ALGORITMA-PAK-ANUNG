# %%
"""
* Dinda Mutia
* NIM: 065002500020
"""

print("Masukan data kamu dengan sesuai!")
nama = input("Masukan nama lengkap:")
alamat = input("Alamat/Tempat tinggal:")
nama_kampus = input("Nama Kampus:")
jurusan = input("Masukan Jurusan Kamu:")
lokasi_gedung = input("Di mana gedung kampus jurusan kamu:")


print("Berikut data kamu!")

print(f"Halo nama saya {nama}, saya tinggal di {alamat}, saya kuliah di {nama_kampus} jurusan {jurusan} di gedung {lokasi_gedung}, dan saya siap ikuti praktikum algoritma")
# Out:
# Masukan data kamu dengan sesuai!
# Masukan nama lengkap:Dinda
# Alamat/Tempat tinggal:Jakarta
# Nama Kampus:Trisakti
# Masukan Jurusan Kamu:Sistem Informasi
# Di mana gedung kampus jurusan kamu:E
# Berikut data kamu!
# Halo nama saya Dinda, saya tinggal di Jakarta, saya kuliah di Trisakti jurusan Sistem Informasi di gedung E, dan saya siap ikuti praktikum algoritma
